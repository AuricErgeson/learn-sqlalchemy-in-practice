# %%
from sqlalchemy import select
from models import Product
from db import Session

# %%
q = select(Product)
print(q)

# %%
session = Session()

# %%
r = session.execute(q)
list(r)

# %%
session.execute(q).all()
# Out:
# 2026-08-27 14:07:17,272 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products
# 2026-08-27 14:07:17,273 INFO sqlalchemy.engine.Engine [cached since 404.4s ago] ()
# [(Product(1, "Acorn Atom"),),
#  (Product(2, "BBC Micro"),),
#  (Product(3, "Electron"),),
#  (Product(4, "BBC Master"),),
#  (Product(5, "Acorn Archimedes"),),
#  (Product(6, "A7000"),),
#  (Product(7, "CPC 464"),),
#  (Product(8, "CPC 664"),),
#  (Product(9, "CPC 6128"),),
#  (Product(10, "464 Plus"),),
#  (Product(11, "6128 Plus"),),
#  (Product(12, "PCW"),),
#  (Product(13, "PC-1512"),),
#  (Product(14, "CEC-I Zhonghua"),),
#  (Product(15, "Imagination Machine"),),
#  (Product(16, "Apple II"),),
#  (Product(17, "Apple IIe"),),
#  (Product(18, "Apple IIc"),),
#  (Product(19, "Apple IIc Plus"),),
#  (Product(20, "Apple II Plus"),),
#  (Product(21, "Apple IIGS"),),
#  (Product(22, "Apricot F1"),),
#  (Product(23, "CT-80"),),
#  (Product(24, "Atari 400"),),
#  (Product(25, "Atari 800"),),
#  (Product(26, "Atari 1200XL"),),
#  (Product(27, "Atari 600XL"),),
#  (Product(28, "Atari 800XL"),),
#  (Product(29, "Atari 65XE"),),
#  (Product(30, "Atari 130XE"),),
#  (Product(31, "Atari ST"),),
#  (Product(32, "Atari TT"),),
#  (Product(33, "Falcon"),),
#  (Product(34, "Bally Brain"),),
#  (Product(35, "Bally Astrocade"),),
#  (Product(36, "CoBra"),),
#  (Product(37, "Lynx"),),
#  (Product(38, "Coleco Adam"),),
#  (Product(39, "PET"),),
#  (Product(40, "VIC-20"),),
#  (Product(41, "Commodore 64"),),
#  (Product(42, "Commodore Executive 64"),),
#  (Product(43, "MAX Machine"),),
#  (Product(44, "Commodore 16"),),
#  (Product(45, "Commodore 116"),),
#  (Product(46, "Plus/4"),),
#  (Product(47, "Commodore 128"),),
#  (Product(48, "Amiga"),),
#  (Product(49, "Comx-35"),),
#  (Product(50, "DAI Personal Computer"),),
#  (Product(51, "VTech Laser 200"),),
#  (Product(52, "Video Genie"),),
#  (Product(53, "Colour Genie"),),
#  (Product(54, "Rabbit RX83"),),
#  (Product(55, "Alpha"),),
#  (Product(56, "Beta"),),
#  (Product(57, "Gama"),),
#  (Product(58, "Dragon 32"),),
#  (Product(59, "Dragon 64"),),
#  (Product(60, "Dubna 48K"),),
#  (Product(61, "BK-0010"),),
#  (Product(62, "AGAT-9"),),
#  (Product(63, "Pecom 32"),),
#  (Product(64, "Pecom 64"),),
#  (Product(65, "Exidy Sorcerer"),),
#  (Product(66, "Enterprise 64"),),
#  (Product(67, "Enterprise 128"),),
#  (Product(68, "Lambda 8300"),),
#  (Product(69, "Franklin ACE"),),
#  (Product(70, "FM Towns"),),
#  (Product(71, "FM-7"),),
#  (Product(72, "Grundy NewBrain"),),
#  (Product(73, "Gradiente Expert"),),
#  (Product(74, "Honeywell 316"),),
#  (Product(75, "PCjr"),),
#  (Product(76, "IBM PS/1"),),
#  (Product(77, "Interact Home Computer"),),
#  (Product(78, "Compucolor II"),),
#  (Product(79, "Hobbit"),),
#  (Product(80, "Iskra-1030"),),
#  (Product(81, "Ivel Ultra"),),
#  (Product(82, "Ivel Z3"),),
#  (Product(83, "Jupiter ACE"),),
#  (Product(84, "ABC 80"),),
#  (Product(85, "Aquarius"),),
#  (Product(86, "Matra Alice"),),
#  (Product(87, "MTX500"),),
#  (Product(88, "MTX512"),),
#  (Product(89, "RS128"),),
#  (Product(90, "MicroBee"),),
#  (Product(91, "CCE MC-1000"),),
#  (Product(92, "TK82C"),),
#  (Product(93, "SAM CoupÃ©"),),
#  (Product(94, "Microprofessor III"),),
#  (Product(95, "NEC PC-100"),),
#  (Product(96, "PC-6000"),),
#  (Product(97, "PC-8800"),),
#  (Product(98, "TRS-80 Color Computer"),),
#  (Product(99, "TRS-80 Color Computer 2"),),
#  (Product(100, "TRS-80 Color Computer 3"),),
#  (Product(101, "TRS-80 Model I"),),
#  (Product(102, "TRS-80 MC-10"),),
#  (Product(103, "Tandy 1000"),),
#  (Product(104, "Euro PC"),),
#  (Product(105, "Oric 1"),),
#  (Product(106, "Oric Atmos"),),
#  (Product(107, "Oric Telestrat"),),
#  (Product(108, "Galeb"),),
#  (Product(109, "Orao"),),
#  (Product(110, "P2000"),),
#  (Product(111, "G7480"),),
#  (Product(112, "Philips :YES"),),
#  (Product(113, "Pravetz 8"),),
#  (Product(114, "Pravetz 8D"),),
#  (Product(115, "IMKO-1"),),
#  (Product(116, "Poly-1"),),
#  (Product(117, "ProlÃ³gica CP-400"),),
#  (Product(118, "KC 85"),),
#  (Product(119, "KC 87"),),
#  (Product(120, "Z1013"),),
#  (Product(121, "SC-3000"),),
#  (Product(122, "MZ"),),
#  (Product(123, "Sharp X1"),),
#  (Product(124, "Sharp X68000"),),
#  (Product(125, "ZX80"),),
#  (Product(126, "ZX81"),),
#  (Product(127, "ZX Spectrum"),),
#  (Product(128, "Sinclair QL"),),
#  (Product(129, "Sord M200 Smart Home Computer"),),
#  (Product(130, "Sord M5"),),
#  (Product(131, "Aamber Pegasus"),),
#  (Product(132, "TI-99/4"),),
#  (Product(133, "TI-99/4A"),),
#  (Product(134, "PMD 85"),),
#  (Product(135, "MAÅ¤O"),),
#  (Product(136, "TO7"),),
#  (Product(137, "MO5"),),
#  (Product(138, "Timex Sinclair 1000"),),
#  (Product(139, "Timex Sinclair 1500"),),
#  (Product(140, "Timex Sinclair 2048"),),
#  (Product(141, "Timex Computer 2048"),),
#  (Product(142, "Timex Computer 2068"),),
#  (Product(143, "Komputer 2086"),),
#  (Product(144, "Tomy Tutor"),),
#  (Product(145, "Vector-06C"),),
#  (Product(146, "VideoBrain Family Computer"),),
#  (Product(147, "TVC"),),
#  (Product(148, "West PC-800"),),
#  (Product(149, "GEM 1000"),)]

# %%
session.execute(q).first()
# Out:
# 2026-08-27 14:07:55,961 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products
# 2026-08-27 14:07:55,962 INFO sqlalchemy.engine.Engine [cached since 443.1s ago] ()
# (Product(1, "Acorn Atom"),)

# %%
session.scalars(q).all()
# Out:
# 2026-08-27 14:16:28,122 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products
# 2026-08-27 14:16:28,123 INFO sqlalchemy.engine.Engine [cached since 955.3s ago] ()
# [Product(1, "Acorn Atom"),
#  Product(2, "BBC Micro"),
#  Product(3, "Electron"),
#  Product(4, "BBC Master"),
#  Product(5, "Acorn Archimedes"),
#  Product(6, "A7000"),
#  Product(7, "CPC 464"),
#  Product(8, "CPC 664"),
#  Product(9, "CPC 6128"),
#  Product(10, "464 Plus"),
#  Product(11, "6128 Plus"),
#  Product(12, "PCW"),
#  Product(13, "PC-1512"),
#  Product(14, "CEC-I Zhonghua"),
#  Product(15, "Imagination Machine"),
#  Product(16, "Apple II"),
#  Product(17, "Apple IIe"),
#  Product(18, "Apple IIc"),
#  Product(19, "Apple IIc Plus"),
#  Product(20, "Apple II Plus"),
#  Product(21, "Apple IIGS"),
#  Product(22, "Apricot F1"),
#  Product(23, "CT-80"),
#  Product(24, "Atari 400"),
#  Product(25, "Atari 800"),
#  Product(26, "Atari 1200XL"),
#  Product(27, "Atari 600XL"),
#  Product(28, "Atari 800XL"),
#  Product(29, "Atari 65XE"),
#  Product(30, "Atari 130XE"),
#  Product(31, "Atari ST"),
#  Product(32, "Atari TT"),
#  Product(33, "Falcon"),
#  Product(34, "Bally Brain"),
#  Product(35, "Bally Astrocade"),
#  Product(36, "CoBra"),
#  Product(37, "Lynx"),
#  Product(38, "Coleco Adam"),
#  Product(39, "PET"),
#  Product(40, "VIC-20"),
#  Product(41, "Commodore 64"),
#  Product(42, "Commodore Executive 64"),
#  Product(43, "MAX Machine"),
#  Product(44, "Commodore 16"),
#  Product(45, "Commodore 116"),
#  Product(46, "Plus/4"),
#  Product(47, "Commodore 128"),
#  Product(48, "Amiga"),
#  Product(49, "Comx-35"),
#  Product(50, "DAI Personal Computer"),
#  Product(51, "VTech Laser 200"),
#  Product(52, "Video Genie"),
#  Product(53, "Colour Genie"),
#  Product(54, "Rabbit RX83"),
#  Product(55, "Alpha"),
#  Product(56, "Beta"),
#  Product(57, "Gama"),
#  Product(58, "Dragon 32"),
#  Product(59, "Dragon 64"),
#  Product(60, "Dubna 48K"),
#  Product(61, "BK-0010"),
#  Product(62, "AGAT-9"),
#  Product(63, "Pecom 32"),
#  Product(64, "Pecom 64"),
#  Product(65, "Exidy Sorcerer"),
#  Product(66, "Enterprise 64"),
#  Product(67, "Enterprise 128"),
#  Product(68, "Lambda 8300"),
#  Product(69, "Franklin ACE"),
#  Product(70, "FM Towns"),
#  Product(71, "FM-7"),
#  Product(72, "Grundy NewBrain"),
#  Product(73, "Gradiente Expert"),
#  Product(74, "Honeywell 316"),
#  Product(75, "PCjr"),
#  Product(76, "IBM PS/1"),
#  Product(77, "Interact Home Computer"),
#  Product(78, "Compucolor II"),
#  Product(79, "Hobbit"),
#  Product(80, "Iskra-1030"),
#  Product(81, "Ivel Ultra"),
#  Product(82, "Ivel Z3"),
#  Product(83, "Jupiter ACE"),
#  Product(84, "ABC 80"),
#  Product(85, "Aquarius"),
#  Product(86, "Matra Alice"),
#  Product(87, "MTX500"),
#  Product(88, "MTX512"),
#  Product(89, "RS128"),
#  Product(90, "MicroBee"),
#  Product(91, "CCE MC-1000"),
#  Product(92, "TK82C"),
#  Product(93, "SAM CoupÃ©"),
#  Product(94, "Microprofessor III"),
#  Product(95, "NEC PC-100"),
#  Product(96, "PC-6000"),
#  Product(97, "PC-8800"),
#  Product(98, "TRS-80 Color Computer"),
#  Product(99, "TRS-80 Color Computer 2"),
#  Product(100, "TRS-80 Color Computer 3"),
#  Product(101, "TRS-80 Model I"),
#  Product(102, "TRS-80 MC-10"),
#  Product(103, "Tandy 1000"),
#  Product(104, "Euro PC"),
#  Product(105, "Oric 1"),
#  Product(106, "Oric Atmos"),
#  Product(107, "Oric Telestrat"),
#  Product(108, "Galeb"),
#  Product(109, "Orao"),
#  Product(110, "P2000"),
#  Product(111, "G7480"),
#  Product(112, "Philips :YES"),
#  Product(113, "Pravetz 8"),
#  Product(114, "Pravetz 8D"),
#  Product(115, "IMKO-1"),
#  Product(116, "Poly-1"),
#  Product(117, "ProlÃ³gica CP-400"),
#  Product(118, "KC 85"),
#  Product(119, "KC 87"),
#  Product(120, "Z1013"),
#  Product(121, "SC-3000"),
#  Product(122, "MZ"),
#  Product(123, "Sharp X1"),
#  Product(124, "Sharp X68000"),
#  Product(125, "ZX80"),
#  Product(126, "ZX81"),
#  Product(127, "ZX Spectrum"),
#  Product(128, "Sinclair QL"),
#  Product(129, "Sord M200 Smart Home Computer"),
#  Product(130, "Sord M5"),
#  Product(131, "Aamber Pegasus"),
#  Product(132, "TI-99/4"),
#  Product(133, "TI-99/4A"),
#  Product(134, "PMD 85"),
#  Product(135, "MAÅ¤O"),
#  Product(136, "TO7"),
#  Product(137, "MO5"),
#  Product(138, "Timex Sinclair 1000"),
#  Product(139, "Timex Sinclair 1500"),
#  Product(140, "Timex Sinclair 2048"),
#  Product(141, "Timex Computer 2048"),
#  Product(142, "Timex Computer 2068"),
#  Product(143, "Komputer 2086"),
#  Product(144, "Tomy Tutor"),
#  Product(145, "Vector-06C"),
#  Product(146, "VideoBrain Family Computer"),
#  Product(147, "TVC"),
#  Product(148, "West PC-800"),
#  Product(149, "GEM 1000")]

# %%
session.scalar(q)
# Out:
# 2026-08-27 14:24:18,376 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products
# 2026-08-27 14:24:18,377 INFO sqlalchemy.engine.Engine [cached since 1426s ago] ()
# Product(1, "Acorn Atom")

# %%
q = select(Product).where(Product.manufacturer == 'Commodore')
session.scalars(q).all()
# Out:
# 2026-08-27 14:56:01,973 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products
# WHERE products.manufacturer = ?
# 2026-08-27 14:56:01,974 INFO sqlalchemy.engine.Engine [cached since 1731s ago] ('Commodore',)
# [Product(39, "PET"),
#  Product(40, "VIC-20"),
#  Product(41, "Commodore 64"),
#  Product(42, "Commodore Executive 64"),
#  Product(43, "MAX Machine"),
#  Product(44, "Commodore 16"),
#  Product(45, "Commodore 116"),
#  Product(46, "Plus/4"),
#  Product(47, "Commodore 128"),
#  Product(48, "Amiga")]

# %%
q = select(Product).where(Product.year >= 1990)
session.scalars(q).all()
# Out:
# 2026-08-27 14:56:59,237 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products
# WHERE products.year >= ?
# 2026-08-27 14:56:59,237 INFO sqlalchemy.engine.Engine [generated in 0.00078s] (1990,)
# [Product(6, "A7000"),
#  Product(10, "464 Plus"),
#  Product(11, "6128 Plus"),
#  Product(32, "Atari TT"),
#  Product(33, "Falcon"),
#  Product(60, "Dubna 48K"),
#  Product(76, "IBM PS/1"),
#  Product(79, "Hobbit")]

# %%
q = (select(Product)
    .where(Product.manufacturer == 'Commodore')
    .where(Product.year == 1980))

session.scalars(q).all()
# Out:
# 2026-08-27 15:01:21,724 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products
# WHERE products.manufacturer = ? AND products.year = ?
# 2026-08-27 15:01:21,724 INFO sqlalchemy.engine.Engine [generated in 0.00063s] ('Commodore', 1980)
# [Product(40, "VIC-20")]

# %%
from sqlalchemy import or_
q = select(Product).where(or_(Product.year < 1970, Product.year > 1990))

session.scalars(q).all()
# Out:
# 2026-08-27 15:07:20,683 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products
# WHERE products.year < ? OR products.year > ?
# 2026-08-27 15:07:20,685 INFO sqlalchemy.engine.Engine [generated in 0.00111s] (1970, 1990)
# [Product(6, "A7000"),
#  Product(33, "Falcon"),
#  Product(60, "Dubna 48K"),
#  Product(74, "Honeywell 316")]

# %%
q = select(Product).where(Product.name.like('%Sinclair%'))
