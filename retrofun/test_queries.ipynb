# %%
from sqlalchemy import select
from models import Product
from db import Session

# %%
q = select(Product)
print(q)
# Out:
# SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products

# %%
session = Session()

# %%
r = session.execute(q)
list(r)
# Out:
# 2026-08-28 08:57:15,634 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-08-28 08:57:15,636 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products
# 2026-08-28 08:57:15,637 INFO sqlalchemy.engine.Engine [generated in 0.00092s] ()
# [(Product(1, "Acorn Atom"),),
#  (Product(2, "BBC Micro"),),
#  (Product(3, "Electron"),),
#  (Product(4, "BBC Master"),),
#  (Product(5, "Acorn Archimedes"),),
#  (Product(6, "A7000"),),
#  (Product(7, "CPC 464"),),
#  (Product(8, "CPC 664"),),
#  (Product(9, "CPC 6128"),),
#  (Product(10, "464 Plus"),),
#  (Product(11, "6128 Plus"),),
#  (Product(12, "PCW"),),
#  (Product(13, "PC-1512"),),
#  (Product(14, "CEC-I Zhonghua"),),
#  (Product(15, "Imagination Machine"),),
#  (Product(16, "Apple II"),),
#  (Product(17, "Apple IIe"),),
#  (Product(18, "Apple IIc"),),
#  (Product(19, "Apple IIc Plus"),),
#  (Product(20, "Apple II Plus"),),
#  (Product(21, "Apple IIGS"),),
#  (Product(22, "Apricot F1"),),
#  (Product(23, "CT-80"),),
#  (Product(24, "Atari 400"),),
#  (Product(25, "Atari 800"),),
#  (Product(26, "Atari 1200XL"),),
#  (Product(27, "Atari 600XL"),),
#  (Product(28, "Atari 800XL"),),
#  (Product(29, "Atari 65XE"),),
#  (Product(30, "Atari 130XE"),),
#  (Product(31, "Atari ST"),),
#  (Product(32, "Atari TT"),),
#  (Product(33, "Falcon"),),
#  (Product(34, "Bally Brain"),),
#  (Product(35, "Bally Astrocade"),),
#  (Product(36, "CoBra"),),
#  (Product(37, "Lynx"),),
#  (Product(38, "Coleco Adam"),),
#  (Product(39, "PET"),),
#  (Product(40, "VIC-20"),),
#  (Product(41, "Commodore 64"),),
#  (Product(42, "Commodore Executive 64"),),
#  (Product(43, "MAX Machine"),),
#  (Product(44, "Commodore 16"),),
#  (Product(45, "Commodore 116"),),
#  (Product(46, "Plus/4"),),
#  (Product(47, "Commodore 128"),),
#  (Product(48, "Amiga"),),
#  (Product(49, "Comx-35"),),
#  (Product(50, "DAI Personal Computer"),),
#  (Product(51, "VTech Laser 200"),),
#  (Product(52, "Video Genie"),),
#  (Product(53, "Colour Genie"),),
#  (Product(54, "Rabbit RX83"),),
#  (Product(55, "Alpha"),),
#  (Product(56, "Beta"),),
#  (Product(57, "Gama"),),
#  (Product(58, "Dragon 32"),),
#  (Product(59, "Dragon 64"),),
#  (Product(60, "Dubna 48K"),),
#  (Product(61, "BK-0010"),),
#  (Product(62, "AGAT-9"),),
#  (Product(63, "Pecom 32"),),
#  (Product(64, "Pecom 64"),),
#  (Product(65, "Exidy Sorcerer"),),
#  (Product(66, "Enterprise 64"),),
#  (Product(67, "Enterprise 128"),),
#  (Product(68, "Lambda 8300"),),
#  (Product(69, "Franklin ACE"),),
#  (Product(70, "FM Towns"),),
#  (Product(71, "FM-7"),),
#  (Product(72, "Grundy NewBrain"),),
#  (Product(73, "Gradiente Expert"),),
#  (Product(74, "Honeywell 316"),),
#  (Product(75, "PCjr"),),
#  (Product(76, "IBM PS/1"),),
#  (Product(77, "Interact Home Computer"),),
#  (Product(78, "Compucolor II"),),
#  (Product(79, "Hobbit"),),
#  (Product(80, "Iskra-1030"),),
#  (Product(81, "Ivel Ultra"),),
#  (Product(82, "Ivel Z3"),),
#  (Product(83, "Jupiter ACE"),),
#  (Product(84, "ABC 80"),),
#  (Product(85, "Aquarius"),),
#  (Product(86, "Matra Alice"),),
#  (Product(87, "MTX500"),),
#  (Product(88, "MTX512"),),
#  (Product(89, "RS128"),),
#  (Product(90, "MicroBee"),),
#  (Product(91, "CCE MC-1000"),),
#  (Product(92, "TK82C"),),
#  (Product(93, "SAM CoupÃ©"),),
#  (Product(94, "Microprofessor III"),),
#  (Product(95, "NEC PC-100"),),
#  (Product(96, "PC-6000"),),
#  (Product(97, "PC-8800"),),
#  (Product(98, "TRS-80 Color Computer"),),
#  (Product(99, "TRS-80 Color Computer 2"),),
#  (Product(100, "TRS-80 Color Computer 3"),),
#  (Product(101, "TRS-80 Model I"),),
#  (Product(102, "TRS-80 MC-10"),),
#  (Product(103, "Tandy 1000"),),
#  (Product(104, "Euro PC"),),
#  (Product(105, "Oric 1"),),
#  (Product(106, "Oric Atmos"),),
#  (Product(107, "Oric Telestrat"),),
#  (Product(108, "Galeb"),),
#  (Product(109, "Orao"),),
#  (Product(110, "P2000"),),
#  (Product(111, "G7480"),),
#  (Product(112, "Philips :YES"),),
#  (Product(113, "Pravetz 8"),),
#  (Product(114, "Pravetz 8D"),),
#  (Product(115, "IMKO-1"),),
#  (Product(116, "Poly-1"),),
#  (Product(117, "ProlÃ³gica CP-400"),),
#  (Product(118, "KC 85"),),
#  (Product(119, "KC 87"),),
#  (Product(120, "Z1013"),),
#  (Product(121, "SC-3000"),),
#  (Product(122, "MZ"),),
#  (Product(123, "Sharp X1"),),
#  (Product(124, "Sharp X68000"),),
#  (Product(125, "ZX80"),),
#  (Product(126, "ZX81"),),
#  (Product(127, "ZX Spectrum"),),
#  (Product(128, "Sinclair QL"),),
#  (Product(129, "Sord M200 Smart Home Computer"),),
#  (Product(130, "Sord M5"),),
#  (Product(131, "Aamber Pegasus"),),
#  (Product(132, "TI-99/4"),),
#  (Product(133, "TI-99/4A"),),
#  (Product(134, "PMD 85"),),
#  (Product(135, "MAÅ¤O"),),
#  (Product(136, "TO7"),),
#  (Product(137, "MO5"),),
#  (Product(138, "Timex Sinclair 1000"),),
#  (Product(139, "Timex Sinclair 1500"),),
#  (Product(140, "Timex Sinclair 2048"),),
#  (Product(141, "Timex Computer 2048"),),
#  (Product(142, "Timex Computer 2068"),),
#  (Product(143, "Komputer 2086"),),
#  (Product(144, "Tomy Tutor"),),
#  (Product(145, "Vector-06C"),),
#  (Product(146, "VideoBrain Family Computer"),),
#  (Product(147, "TVC"),),
#  (Product(148, "West PC-800"),),
#  (Product(149, "GEM 1000"),)]

# %%
session.execute(q).all()
# Out:
# 2026-08-28 08:57:15,774 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products
# 2026-08-28 08:57:15,774 INFO sqlalchemy.engine.Engine [cached since 0.1381s ago] ()
# [(Product(1, "Acorn Atom"),),
#  (Product(2, "BBC Micro"),),
#  (Product(3, "Electron"),),
#  (Product(4, "BBC Master"),),
#  (Product(5, "Acorn Archimedes"),),
#  (Product(6, "A7000"),),
#  (Product(7, "CPC 464"),),
#  (Product(8, "CPC 664"),),
#  (Product(9, "CPC 6128"),),
#  (Product(10, "464 Plus"),),
#  (Product(11, "6128 Plus"),),
#  (Product(12, "PCW"),),
#  (Product(13, "PC-1512"),),
#  (Product(14, "CEC-I Zhonghua"),),
#  (Product(15, "Imagination Machine"),),
#  (Product(16, "Apple II"),),
#  (Product(17, "Apple IIe"),),
#  (Product(18, "Apple IIc"),),
#  (Product(19, "Apple IIc Plus"),),
#  (Product(20, "Apple II Plus"),),
#  (Product(21, "Apple IIGS"),),
#  (Product(22, "Apricot F1"),),
#  (Product(23, "CT-80"),),
#  (Product(24, "Atari 400"),),
#  (Product(25, "Atari 800"),),
#  (Product(26, "Atari 1200XL"),),
#  (Product(27, "Atari 600XL"),),
#  (Product(28, "Atari 800XL"),),
#  (Product(29, "Atari 65XE"),),
#  (Product(30, "Atari 130XE"),),
#  (Product(31, "Atari ST"),),
#  (Product(32, "Atari TT"),),
#  (Product(33, "Falcon"),),
#  (Product(34, "Bally Brain"),),
#  (Product(35, "Bally Astrocade"),),
#  (Product(36, "CoBra"),),
#  (Product(37, "Lynx"),),
#  (Product(38, "Coleco Adam"),),
#  (Product(39, "PET"),),
#  (Product(40, "VIC-20"),),
#  (Product(41, "Commodore 64"),),
#  (Product(42, "Commodore Executive 64"),),
#  (Product(43, "MAX Machine"),),
#  (Product(44, "Commodore 16"),),
#  (Product(45, "Commodore 116"),),
#  (Product(46, "Plus/4"),),
#  (Product(47, "Commodore 128"),),
#  (Product(48, "Amiga"),),
#  (Product(49, "Comx-35"),),
#  (Product(50, "DAI Personal Computer"),),
#  (Product(51, "VTech Laser 200"),),
#  (Product(52, "Video Genie"),),
#  (Product(53, "Colour Genie"),),
#  (Product(54, "Rabbit RX83"),),
#  (Product(55, "Alpha"),),
#  (Product(56, "Beta"),),
#  (Product(57, "Gama"),),
#  (Product(58, "Dragon 32"),),
#  (Product(59, "Dragon 64"),),
#  (Product(60, "Dubna 48K"),),
#  (Product(61, "BK-0010"),),
#  (Product(62, "AGAT-9"),),
#  (Product(63, "Pecom 32"),),
#  (Product(64, "Pecom 64"),),
#  (Product(65, "Exidy Sorcerer"),),
#  (Product(66, "Enterprise 64"),),
#  (Product(67, "Enterprise 128"),),
#  (Product(68, "Lambda 8300"),),
#  (Product(69, "Franklin ACE"),),
#  (Product(70, "FM Towns"),),
#  (Product(71, "FM-7"),),
#  (Product(72, "Grundy NewBrain"),),
#  (Product(73, "Gradiente Expert"),),
#  (Product(74, "Honeywell 316"),),
#  (Product(75, "PCjr"),),
#  (Product(76, "IBM PS/1"),),
#  (Product(77, "Interact Home Computer"),),
#  (Product(78, "Compucolor II"),),
#  (Product(79, "Hobbit"),),
#  (Product(80, "Iskra-1030"),),
#  (Product(81, "Ivel Ultra"),),
#  (Product(82, "Ivel Z3"),),
#  (Product(83, "Jupiter ACE"),),
#  (Product(84, "ABC 80"),),
#  (Product(85, "Aquarius"),),
#  (Product(86, "Matra Alice"),),
#  (Product(87, "MTX500"),),
#  (Product(88, "MTX512"),),
#  (Product(89, "RS128"),),
#  (Product(90, "MicroBee"),),
#  (Product(91, "CCE MC-1000"),),
#  (Product(92, "TK82C"),),
#  (Product(93, "SAM CoupÃ©"),),
#  (Product(94, "Microprofessor III"),),
#  (Product(95, "NEC PC-100"),),
#  (Product(96, "PC-6000"),),
#  (Product(97, "PC-8800"),),
#  (Product(98, "TRS-80 Color Computer"),),
#  (Product(99, "TRS-80 Color Computer 2"),),
#  (Product(100, "TRS-80 Color Computer 3"),),
#  (Product(101, "TRS-80 Model I"),),
#  (Product(102, "TRS-80 MC-10"),),
#  (Product(103, "Tandy 1000"),),
#  (Product(104, "Euro PC"),),
#  (Product(105, "Oric 1"),),
#  (Product(106, "Oric Atmos"),),
#  (Product(107, "Oric Telestrat"),),
#  (Product(108, "Galeb"),),
#  (Product(109, "Orao"),),
#  (Product(110, "P2000"),),
#  (Product(111, "G7480"),),
#  (Product(112, "Philips :YES"),),
#  (Product(113, "Pravetz 8"),),
#  (Product(114, "Pravetz 8D"),),
#  (Product(115, "IMKO-1"),),
#  (Product(116, "Poly-1"),),
#  (Product(117, "ProlÃ³gica CP-400"),),
#  (Product(118, "KC 85"),),
#  (Product(119, "KC 87"),),
#  (Product(120, "Z1013"),),
#  (Product(121, "SC-3000"),),
#  (Product(122, "MZ"),),
#  (Product(123, "Sharp X1"),),
#  (Product(124, "Sharp X68000"),),
#  (Product(125, "ZX80"),),
#  (Product(126, "ZX81"),),
#  (Product(127, "ZX Spectrum"),),
#  (Product(128, "Sinclair QL"),),
#  (Product(129, "Sord M200 Smart Home Computer"),),
#  (Product(130, "Sord M5"),),
#  (Product(131, "Aamber Pegasus"),),
#  (Product(132, "TI-99/4"),),
#  (Product(133, "TI-99/4A"),),
#  (Product(134, "PMD 85"),),
#  (Product(135, "MAÅ¤O"),),
#  (Product(136, "TO7"),),
#  (Product(137, "MO5"),),
#  (Product(138, "Timex Sinclair 1000"),),
#  (Product(139, "Timex Sinclair 1500"),),
#  (Product(140, "Timex Sinclair 2048"),),
#  (Product(141, "Timex Computer 2048"),),
#  (Product(142, "Timex Computer 2068"),),
#  (Product(143, "Komputer 2086"),),
#  (Product(144, "Tomy Tutor"),),
#  (Product(145, "Vector-06C"),),
#  (Product(146, "VideoBrain Family Computer"),),
#  (Product(147, "TVC"),),
#  (Product(148, "West PC-800"),),
#  (Product(149, "GEM 1000"),)]

# %%
session.execute(q).first()
# Out:
# 2026-08-28 08:57:15,887 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products
# 2026-08-28 08:57:15,887 INFO sqlalchemy.engine.Engine [cached since 0.2511s ago] ()
# (Product(1, "Acorn Atom"),)

# %%
session.scalars(q).all()
# Out:
# 2026-08-28 08:57:15,973 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products
# 2026-08-28 08:57:15,974 INFO sqlalchemy.engine.Engine [cached since 0.3375s ago] ()
# [Product(1, "Acorn Atom"),
#  Product(2, "BBC Micro"),
#  Product(3, "Electron"),
#  Product(4, "BBC Master"),
#  Product(5, "Acorn Archimedes"),
#  Product(6, "A7000"),
#  Product(7, "CPC 464"),
#  Product(8, "CPC 664"),
#  Product(9, "CPC 6128"),
#  Product(10, "464 Plus"),
#  Product(11, "6128 Plus"),
#  Product(12, "PCW"),
#  Product(13, "PC-1512"),
#  Product(14, "CEC-I Zhonghua"),
#  Product(15, "Imagination Machine"),
#  Product(16, "Apple II"),
#  Product(17, "Apple IIe"),
#  Product(18, "Apple IIc"),
#  Product(19, "Apple IIc Plus"),
#  Product(20, "Apple II Plus"),
#  Product(21, "Apple IIGS"),
#  Product(22, "Apricot F1"),
#  Product(23, "CT-80"),
#  Product(24, "Atari 400"),
#  Product(25, "Atari 800"),
#  Product(26, "Atari 1200XL"),
#  Product(27, "Atari 600XL"),
#  Product(28, "Atari 800XL"),
#  Product(29, "Atari 65XE"),
#  Product(30, "Atari 130XE"),
#  Product(31, "Atari ST"),
#  Product(32, "Atari TT"),
#  Product(33, "Falcon"),
#  Product(34, "Bally Brain"),
#  Product(35, "Bally Astrocade"),
#  Product(36, "CoBra"),
#  Product(37, "Lynx"),
#  Product(38, "Coleco Adam"),
#  Product(39, "PET"),
#  Product(40, "VIC-20"),
#  Product(41, "Commodore 64"),
#  Product(42, "Commodore Executive 64"),
#  Product(43, "MAX Machine"),
#  Product(44, "Commodore 16"),
#  Product(45, "Commodore 116"),
#  Product(46, "Plus/4"),
#  Product(47, "Commodore 128"),
#  Product(48, "Amiga"),
#  Product(49, "Comx-35"),
#  Product(50, "DAI Personal Computer"),
#  Product(51, "VTech Laser 200"),
#  Product(52, "Video Genie"),
#  Product(53, "Colour Genie"),
#  Product(54, "Rabbit RX83"),
#  Product(55, "Alpha"),
#  Product(56, "Beta"),
#  Product(57, "Gama"),
#  Product(58, "Dragon 32"),
#  Product(59, "Dragon 64"),
#  Product(60, "Dubna 48K"),
#  Product(61, "BK-0010"),
#  Product(62, "AGAT-9"),
#  Product(63, "Pecom 32"),
#  Product(64, "Pecom 64"),
#  Product(65, "Exidy Sorcerer"),
#  Product(66, "Enterprise 64"),
#  Product(67, "Enterprise 128"),
#  Product(68, "Lambda 8300"),
#  Product(69, "Franklin ACE"),
#  Product(70, "FM Towns"),
#  Product(71, "FM-7"),
#  Product(72, "Grundy NewBrain"),
#  Product(73, "Gradiente Expert"),
#  Product(74, "Honeywell 316"),
#  Product(75, "PCjr"),
#  Product(76, "IBM PS/1"),
#  Product(77, "Interact Home Computer"),
#  Product(78, "Compucolor II"),
#  Product(79, "Hobbit"),
#  Product(80, "Iskra-1030"),
#  Product(81, "Ivel Ultra"),
#  Product(82, "Ivel Z3"),
#  Product(83, "Jupiter ACE"),
#  Product(84, "ABC 80"),
#  Product(85, "Aquarius"),
#  Product(86, "Matra Alice"),
#  Product(87, "MTX500"),
#  Product(88, "MTX512"),
#  Product(89, "RS128"),
#  Product(90, "MicroBee"),
#  Product(91, "CCE MC-1000"),
#  Product(92, "TK82C"),
#  Product(93, "SAM CoupÃ©"),
#  Product(94, "Microprofessor III"),
#  Product(95, "NEC PC-100"),
#  Product(96, "PC-6000"),
#  Product(97, "PC-8800"),
#  Product(98, "TRS-80 Color Computer"),
#  Product(99, "TRS-80 Color Computer 2"),
#  Product(100, "TRS-80 Color Computer 3"),
#  Product(101, "TRS-80 Model I"),
#  Product(102, "TRS-80 MC-10"),
#  Product(103, "Tandy 1000"),
#  Product(104, "Euro PC"),
#  Product(105, "Oric 1"),
#  Product(106, "Oric Atmos"),
#  Product(107, "Oric Telestrat"),
#  Product(108, "Galeb"),
#  Product(109, "Orao"),
#  Product(110, "P2000"),
#  Product(111, "G7480"),
#  Product(112, "Philips :YES"),
#  Product(113, "Pravetz 8"),
#  Product(114, "Pravetz 8D"),
#  Product(115, "IMKO-1"),
#  Product(116, "Poly-1"),
#  Product(117, "ProlÃ³gica CP-400"),
#  Product(118, "KC 85"),
#  Product(119, "KC 87"),
#  Product(120, "Z1013"),
#  Product(121, "SC-3000"),
#  Product(122, "MZ"),
#  Product(123, "Sharp X1"),
#  Product(124, "Sharp X68000"),
#  Product(125, "ZX80"),
#  Product(126, "ZX81"),
#  Product(127, "ZX Spectrum"),
#  Product(128, "Sinclair QL"),
#  Product(129, "Sord M200 Smart Home Computer"),
#  Product(130, "Sord M5"),
#  Product(131, "Aamber Pegasus"),
#  Product(132, "TI-99/4"),
#  Product(133, "TI-99/4A"),
#  Product(134, "PMD 85"),
#  Product(135, "MAÅ¤O"),
#  Product(136, "TO7"),
#  Product(137, "MO5"),
#  Product(138, "Timex Sinclair 1000"),
#  Product(139, "Timex Sinclair 1500"),
#  Product(140, "Timex Sinclair 2048"),
#  Product(141, "Timex Computer 2048"),
#  Product(142, "Timex Computer 2068"),
#  Product(143, "Komputer 2086"),
#  Product(144, "Tomy Tutor"),
#  Product(145, "Vector-06C"),
#  Product(146, "VideoBrain Family Computer"),
#  Product(147, "TVC"),
#  Product(148, "West PC-800"),
#  Product(149, "GEM 1000")]

# %%
session.scalar(q)
# Out:
# 2026-08-28 08:57:16,030 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products
# 2026-08-28 08:57:16,031 INFO sqlalchemy.engine.Engine [cached since 0.3952s ago] ()
# Product(1, "Acorn Atom")

# %%
q = select(Product).where(Product.manufacturer == 'Commodore')
session.scalars(q).all()
# Out:
# 2026-08-28 08:57:16,130 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products
# WHERE products.manufacturer = ?
# 2026-08-28 08:57:16,131 INFO sqlalchemy.engine.Engine [generated in 0.00101s] ('Commodore',)
# [Product(39, "PET"),
#  Product(40, "VIC-20"),
#  Product(41, "Commodore 64"),
#  Product(42, "Commodore Executive 64"),
#  Product(43, "MAX Machine"),
#  Product(44, "Commodore 16"),
#  Product(45, "Commodore 116"),
#  Product(46, "Plus/4"),
#  Product(47, "Commodore 128"),
#  Product(48, "Amiga")]

# %%
q = select(Product).where(Product.year >= 1990)
session.scalars(q).all()
# Out:
# 2026-08-28 08:57:16,171 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products
# WHERE products.year >= ?
# 2026-08-28 08:57:16,173 INFO sqlalchemy.engine.Engine [generated in 0.00183s] (1990,)
# [Product(6, "A7000"),
#  Product(10, "464 Plus"),
#  Product(11, "6128 Plus"),
#  Product(32, "Atari TT"),
#  Product(33, "Falcon"),
#  Product(60, "Dubna 48K"),
#  Product(76, "IBM PS/1"),
#  Product(79, "Hobbit")]

# %%
q = (select(Product)
    .where(Product.manufacturer == 'Commodore')
    .where(Product.year == 1980))

session.scalars(q).all()
# Out:
# 2026-08-28 08:57:16,247 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products
# WHERE products.manufacturer = ? AND products.year = ?
# 2026-08-28 08:57:16,248 INFO sqlalchemy.engine.Engine [generated in 0.00114s] ('Commodore', 1980)
# [Product(40, "VIC-20")]

# %%
from sqlalchemy import or_
q = select(Product).where(or_(Product.year < 1970, Product.year > 1990))

session.scalars(q).all()
# Out:
# 2026-08-28 08:57:16,286 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products
# WHERE products.year < ? OR products.year > ?
# 2026-08-28 08:57:16,287 INFO sqlalchemy.engine.Engine [generated in 0.00109s] (1970, 1990)
# [Product(6, "A7000"),
#  Product(33, "Falcon"),
#  Product(60, "Dubna 48K"),
#  Product(74, "Honeywell 316")]

# %%
q = select(Product).where(Product.name.like('%Sinclair%'))

# %%
q = select(Product).order_by(Product.year.desc())
session.scalars(q).all()
# Out:
# 2026-08-28 09:02:24,613 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products ORDER BY products.year DESC
# 2026-08-28 09:02:24,614 INFO sqlalchemy.engine.Engine [generated in 0.00091s] ()
# [Product(6, "A7000"),
#  Product(33, "Falcon"),
#  Product(60, "Dubna 48K"),
#  Product(10, "464 Plus"),
#  Product(11, "6128 Plus"),
#  Product(32, "Atari TT"),
#  Product(76, "IBM PS/1"),
#  Product(79, "Hobbit"),
#  Product(70, "FM Towns"),
#  Product(80, "Iskra-1030"),
#  Product(93, "SAM CoupÃ©"),
#  Product(135, "MAÅ¤O"),
#  Product(19, "Apple IIc Plus"),
#  Product(104, "Euro PC"),
#  Product(5, "Acorn Archimedes"),
#  Product(57, "Gama"),
#  Product(103, "Tandy 1000"),
#  Product(119, "KC 87"),
#  Product(124, "Sharp X68000"),
#  Product(145, "Vector-06C"),
#  Product(4, "BBC Master"),
#  Product(13, "PC-1512"),
#  Product(14, "CEC-I Zhonghua"),
#  Product(21, "Apple IIGS"),
#  Product(36, "CoBra"),
#  Product(55, "Alpha"),
#  Product(56, "Beta"),
#  Product(107, "Oric Telestrat"),
#  Product(143, "Komputer 2086"),
#  Product(144, "Tomy Tutor"),
#  Product(147, "TVC"),
#  Product(12, "PCW"),
#  Product(29, "Atari 65XE"),
#  Product(30, "Atari 130XE"),
#  Product(31, "Atari ST"),
#  Product(47, "Commodore 128"),
#  Product(48, "Amiga"),
#  Product(51, "VTech Laser 200"),
#  Product(61, "BK-0010"),
#  Product(63, "Pecom 32"),
#  Product(64, "Pecom 64"),
#  Product(66, "Enterprise 64"),
#  Product(67, "Enterprise 128"),
#  Product(68, "Lambda 8300"),
#  Product(73, "Gradiente Expert"),
#  Product(91, "CCE MC-1000"),
#  Product(92, "TK82C"),
#  Product(112, "Philips :YES"),
#  Product(113, "Pravetz 8"),
#  Product(120, "Z1013"),
#  Product(134, "PMD 85"),
#  Product(149, "GEM 1000"),
#  Product(7, "CPC 464"),
#  Product(8, "CPC 664"),
#  Product(9, "CPC 6128"),
#  Product(18, "Apple IIc"),
#  Product(22, "Apricot F1"),
#  Product(44, "Commodore 16"),
#  Product(45, "Commodore 116"),
#  Product(46, "Plus/4"),
#  Product(62, "AGAT-9"),
#  Product(75, "PCjr"),
#  Product(81, "Ivel Ultra"),
#  Product(106, "Oric Atmos"),
#  Product(109, "Orao"),
#  Product(117, "ProlÃ³gica CP-400"),
#  Product(118, "KC 85"),
#  Product(128, "Sinclair QL"),
#  Product(131, "Aamber Pegasus"),
#  Product(137, "MO5"),
#  Product(140, "Timex Sinclair 2048"),
#  Product(141, "Timex Computer 2048"),
#  Product(148, "West PC-800"),
#  Product(3, "Electron"),
#  Product(17, "Apple IIe"),
#  Product(26, "Atari 1200XL"),
#  Product(27, "Atari 600XL"),
#  Product(28, "Atari 800XL"),
#  Product(37, "Lynx"),
#  Product(38, "Coleco Adam"),
#  Product(49, "Comx-35"),
#  Product(53, "Colour Genie"),
#  Product(54, "Rabbit RX83"),
#  Product(82, "Ivel Z3"),
#  Product(85, "Aquarius"),
#  Product(86, "Matra Alice"),
#  Product(87, "MTX500"),
#  Product(88, "MTX512"),
#  Product(89, "RS128"),
#  Product(90, "MicroBee"),
#  Product(94, "Microprofessor III"),
#  Product(95, "NEC PC-100"),
#  Product(102, "TRS-80 MC-10"),
#  Product(105, "Oric 1"),
#  Product(111, "G7480"),
#  Product(121, "SC-3000"),
#  Product(142, "Timex Computer 2068"),
#  Product(23, "CT-80"),
#  Product(41, "Commodore 64"),
#  Product(42, "Commodore Executive 64"),
#  Product(43, "MAX Machine"),
#  Product(58, "Dragon 32"),
#  Product(59, "Dragon 64"),
#  Product(69, "Franklin ACE"),
#  Product(71, "FM-7"),
#  Product(72, "Grundy NewBrain"),
#  Product(83, "Jupiter ACE"),
#  Product(114, "Pravetz 8D"),
#  Product(123, "Sharp X1"),
#  Product(127, "ZX Spectrum"),
#  Product(130, "Sord M5"),
#  Product(136, "TO7"),
#  Product(138, "Timex Sinclair 1000"),
#  Product(139, "Timex Sinclair 1500"),
#  Product(2, "BBC Micro"),
#  Product(96, "PC-6000"),
#  Product(97, "PC-8800"),
#  Product(108, "Galeb"),
#  Product(116, "Poly-1"),
#  Product(126, "ZX81"),
#  Product(1, "Acorn Atom"),
#  Product(40, "VIC-20"),
#  Product(50, "DAI Personal Computer"),
#  Product(52, "Video Genie"),
#  Product(98, "TRS-80 Color Computer"),
#  Product(99, "TRS-80 Color Computer 2"),
#  Product(100, "TRS-80 Color Computer 3"),
#  Product(110, "P2000"),
#  Product(115, "IMKO-1"),
#  Product(125, "ZX80"),
#  Product(15, "Imagination Machine"),
#  Product(20, "Apple II Plus"),
#  Product(24, "Atari 400"),
#  Product(25, "Atari 800"),
#  Product(34, "Bally Brain"),
#  Product(77, "Interact Home Computer"),
#  Product(122, "MZ"),
#  Product(132, "TI-99/4"),
#  Product(133, "TI-99/4A"),
#  Product(65, "Exidy Sorcerer"),
#  Product(84, "ABC 80"),
#  Product(16, "Apple II"),
#  Product(35, "Bally Astrocade"),
#  Product(39, "PET"),
#  Product(78, "Compucolor II"),
#  Product(101, "TRS-80 Model I"),
#  Product(129, "Sord M200 Smart Home Computer"),
#  Product(146, "VideoBrain Family Computer"),
#  Product(74, "Honeywell 316")]

# %%
q = select(Product.name)
session.scalars(q).all()
# Out:
# 2026-08-28 09:03:20,001 INFO sqlalchemy.engine.Engine SELECT products.name
# FROM products
# 2026-08-28 09:03:20,002 INFO sqlalchemy.engine.Engine [generated in 0.00082s] ()
# ['Acorn Atom',
#  'BBC Micro',
#  'Electron',
#  'BBC Master',
#  'Acorn Archimedes',
#  'A7000',
#  'CPC 464',
#  'CPC 664',
#  'CPC 6128',
#  '464 Plus',
#  '6128 Plus',
#  'PCW',
#  'PC-1512',
#  'CEC-I Zhonghua',
#  'Imagination Machine',
#  'Apple II',
#  'Apple IIe',
#  'Apple IIc',
#  'Apple IIc Plus',
#  'Apple II Plus',
#  'Apple IIGS',
#  'Apricot F1',
#  'CT-80',
#  'Atari 400',
#  'Atari 800',
#  'Atari 1200XL',
#  'Atari 600XL',
#  'Atari 800XL',
#  'Atari 65XE',
#  'Atari 130XE',
#  'Atari ST',
#  'Atari TT',
#  'Falcon',
#  'Bally Brain',
#  'Bally Astrocade',
#  'CoBra',
#  'Lynx',
#  'Coleco Adam',
#  'PET',
#  'VIC-20',
#  'Commodore 64',
#  'Commodore Executive 64',
#  'MAX Machine',
#  'Commodore 16',
#  'Commodore 116',
#  'Plus/4',
#  'Commodore 128',
#  'Amiga',
#  'Comx-35',
#  'DAI Personal Computer',
#  'VTech Laser 200',
#  'Video Genie',
#  'Colour Genie',
#  'Rabbit RX83',
#  'Alpha',
#  'Beta',
#  'Gama',
#  'Dragon 32',
#  'Dragon 64',
#  'Dubna 48K',
#  'BK-0010',
#  'AGAT-9',
#  'Pecom 32',
#  'Pecom 64',
#  'Exidy Sorcerer',
#  'Enterprise 64',
#  'Enterprise 128',
#  'Lambda 8300',
#  'Franklin ACE',
#  'FM Towns',
#  'FM-7',
#  'Grundy NewBrain',
#  'Gradiente Expert',
#  'Honeywell 316',
#  'PCjr',
#  'IBM PS/1',
#  'Interact Home Computer',
#  'Compucolor II',
#  'Hobbit',
#  'Iskra-1030',
#  'Ivel Ultra',
#  'Ivel Z3',
#  'Jupiter ACE',
#  'ABC 80',
#  'Aquarius',
#  'Matra Alice',
#  'MTX500',
#  'MTX512',
#  'RS128',
#  'MicroBee',
#  'CCE MC-1000',
#  'TK82C',
#  'SAM CoupÃ©',
#  'Microprofessor III',
#  'NEC PC-100',
#  'PC-6000',
#  'PC-8800',
#  'TRS-80 Color Computer',
#  'TRS-80 Color Computer 2',
#  'TRS-80 Color Computer 3',
#  'TRS-80 Model I',
#  'TRS-80 MC-10',
#  'Tandy 1000',
#  'Euro PC',
#  'Oric 1',
#  'Oric Atmos',
#  'Oric Telestrat',
#  'Galeb',
#  'Orao',
#  'P2000',
#  'G7480',
#  'Philips :YES',
#  'Pravetz 8',
#  'Pravetz 8D',
#  'IMKO-1',
#  'Poly-1',
#  'ProlÃ³gica CP-400',
#  'KC 85',
#  'KC 87',
#  'Z1013',
#  'SC-3000',
#  'MZ',
#  'Sharp X1',
#  'Sharp X68000',
#  'ZX80',
#  'ZX81',
#  'ZX Spectrum',
#  'Sinclair QL',
#  'Sord M200 Smart Home Computer',
#  'Sord M5',
#  'Aamber Pegasus',
#  'TI-99/4',
#  'TI-99/4A',
#  'PMD 85',
#  'MAÅ¤O',
#  'TO7',
#  'MO5',
#  'Timex Sinclair 1000',
#  'Timex Sinclair 1500',
#  'Timex Sinclair 2048',
#  'Timex Computer 2048',
#  'Timex Computer 2068',
#  'Komputer 2086',
#  'Tomy Tutor',
#  'Vector-06C',
#  'VideoBrain Family Computer',
#  'TVC',
#  'West PC-800',
#  'GEM 1000']

# %%
from sqlalchemy import func

# %%
q = select(func.count(Product.id))
session.scalar(q)
# Out:
# 2026-08-28 09:14:54,750 INFO sqlalchemy.engine.Engine SELECT count(products.id) AS count_1
# FROM products
# 2026-08-28 09:14:54,751 INFO sqlalchemy.engine.Engine [cached since 15.68s ago] ()
# 149

# %%
q= select(func.min(Product.year),func.max(Product.year))

session.execute(q).first()
# Out:
# 2026-08-28 09:23:33,242 INFO sqlalchemy.engine.Engine SELECT min(products.year) AS min_1, max(products.year) AS max_1
# FROM products
# 2026-08-28 09:23:33,243 INFO sqlalchemy.engine.Engine [cached since 62.34s ago] ()
# (1969, 1995)

# %%
q = select(Product.manufacturer).order_by(Product.manufacturer)
session.scalars(q).all()
# Out:
# 2026-08-28 09:33:56,546 INFO sqlalchemy.engine.Engine SELECT products.manufacturer
# FROM products ORDER BY products.manufacturer
# 2026-08-28 09:33:56,547 INFO sqlalchemy.engine.Engine [generated in 0.00081s] ()
# ['AGAT',
#  'APF Electronics, Inc.',
#  'Acorn Computers Ltd',
#  'Acorn Computers Ltd',
#  'Acorn Computers Ltd',
#  'Acorn Computers Ltd',
#  'Acorn Computers Ltd',
#  'Acorn Computers Ltd',
#  'Amstrad',
#  'Amstrad',
#  'Amstrad',
#  'Amstrad',
#  'Amstrad',
#  'Amstrad',
#  'Amstrad',
#  'Apple Computer',
#  'Apple Computer',
#  'Apple Computer',
#  'Apple Computer',
#  'Apple Computer',
#  'Apple Computer',
#  'Apricot Computers',
#  'Aster Computers',
#  'Atari Corporation',
#  'Atari Corporation',
#  'Atari Corporation',
#  'Atari, Inc.',
#  'Atari, Inc.',
#  'Atari, Inc.',
#  'Atari, Inc.',
#  'Atari, Inc.',
#  'Atari, Inc.',
#  'Atari, Inc.',
#  'Bally Consumer Products',
#  'Bally Consumer Products',
#  'Brasov Computer',
#  'Camputers',
#  'Coleco',
#  'Commodore',
#  'Commodore',
#  'Commodore',
#  'Commodore',
#  'Commodore',
#  'Commodore',
#  'Commodore',
#  'Commodore',
#  'Commodore',
#  'Commodore',
#  'Comx World Operations',
#  'ComÃ©rcio de Componentes EletrÃ´nicos',
#  'Data Applications International',
#  'Didaktik',
#  'Didaktik',
#  'Didaktik',
#  'Dragon Data',
#  'Dragon Data',
#  'Dubna',
#  'EACA',
#  'EACA',
#  'Elektronika',
#  'Elektronska Industrija NiÅ¡',
#  'Elektronska Industrija NiÅ¡',
#  'Exidy',
#  'Franklin Computer Corporation',
#  'Fujitsu',
#  'Fujitsu',
#  'GEM',
#  'Gradiente',
#  'Grundy Business Systems',
#  'Honeywell',
#  'IBM',
#  'IBM',
#  'Intelligent Software',
#  'Intelligent Software',
#  'Intelligent Systems Corporation',
#  'Interact',
#  'Intercompex',
#  'Iskra',
#  'Ivasim',
#  'Ivasim',
#  'Jupiter Cantab',
#  'Lambda Electronics',
#  'Luxor',
#  'Matra',
#  'Mattel',
#  'Memotech',
#  'Memotech',
#  'Memotech',
#  'Microbee Systems',
#  'Microdigital Eletronica',
#  'Miles Gordon Technology',
#  'Multitech',
#  'NEC',
#  'NEC',
#  'NEC Home Electronics',
#  'PEL VaraÅ¾din',
#  'PEL VaraÅ¾din',
#  'Philips',
#  'Philips',
#  'Philips',
#  'Pravetz',
#  'Pravetz',
#  'Pravetz',
#  'Progeni Systems / Polycorp',
#  'ProlÃ³gica',
#  'Rabbit',
#  'Radio Shack',
#  'Radio Shack',
#  'Radio Shack',
#  'Radio Shack',
#  'Radio Shack',
#  'Radio Shack',
#  'Schneider Computer Division',
#  'Sega',
#  'Sharp',
#  'Sharp',
#  'Sharp',
#  'Sinclair Research',
#  'Sinclair Research',
#  'Sinclair Research',
#  'Sinclair Research',
#  'Sord Computer Corporation',
#  'Sord Computer Corporation',
#  'Tangerine Computer Systems',
#  'Tangerine Computer Systems',
#  'Tangerine Computer Systems',
#  'Technosys',
#  'Tesla',
#  'Texas Instruments',
#  'Texas Instruments',
#  'Thomson',
#  'Thomson',
#  'Timex Sinclair',
#  'Timex Sinclair',
#  'Timex Sinclair',
#  'Timex Sinclair',
#  'Timex Sinclair',
#  'Timex Sinclair',
#  'Tomy',
#  'Tsinghua University',
#  'VEB Robotron',
#  'VEB Robotron',
#  'VEB Robotron',
#  'Vector',
#  'Videobrain',
#  'Videoton',
#  'Vtech',
#  'West Computer AS',
#  'Å\xa0tÃ¡tny majetok ZÃ¡vadka Å¡.p.']

# %%
q = select(Product.manufacturer).order_by(Product.manufacturer).distinct()
session.scalars(q).all()
# Out:
# 2026-08-28 09:37:55,430 INFO sqlalchemy.engine.Engine SELECT DISTINCT products.manufacturer
# FROM products ORDER BY products.manufacturer
# 2026-08-28 09:37:55,432 INFO sqlalchemy.engine.Engine [generated in 0.00205s] ()
# ['AGAT',
#  'APF Electronics, Inc.',
#  'Acorn Computers Ltd',
#  'Amstrad',
#  'Apple Computer',
#  'Apricot Computers',
#  'Aster Computers',
#  'Atari Corporation',
#  'Atari, Inc.',
#  'Bally Consumer Products',
#  'Brasov Computer',
#  'Camputers',
#  'Coleco',
#  'Commodore',
#  'Comx World Operations',
#  'ComÃ©rcio de Componentes EletrÃ´nicos',
#  'Data Applications International',
#  'Didaktik',
#  'Dragon Data',
#  'Dubna',
#  'EACA',
#  'Elektronika',
#  'Elektronska Industrija NiÅ¡',
#  'Exidy',
#  'Franklin Computer Corporation',
#  'Fujitsu',
#  'GEM',
#  'Gradiente',
#  'Grundy Business Systems',
#  'Honeywell',
#  'IBM',
#  'Intelligent Software',
#  'Intelligent Systems Corporation',
#  'Interact',
#  'Intercompex',
#  'Iskra',
#  'Ivasim',
#  'Jupiter Cantab',
#  'Lambda Electronics',
#  'Luxor',
#  'Matra',
#  'Mattel',
#  'Memotech',
#  'Microbee Systems',
#  'Microdigital Eletronica',
#  'Miles Gordon Technology',
#  'Multitech',
#  'NEC',
#  'NEC Home Electronics',
#  'PEL VaraÅ¾din',
#  'Philips',
#  'Pravetz',
#  'Progeni Systems / Polycorp',
#  'ProlÃ³gica',
#  'Rabbit',
#  'Radio Shack',
#  'Schneider Computer Division',
#  'Sega',
#  'Sharp',
#  'Sinclair Research',
#  'Sord Computer Corporation',
#  'Tangerine Computer Systems',
#  'Technosys',
#  'Tesla',
#  'Texas Instruments',
#  'Thomson',
#  'Timex Sinclair',
#  'Tomy',
#  'Tsinghua University',
#  'VEB Robotron',
#  'Vector',
#  'Videobrain',
#  'Videoton',
#  'Vtech',
#  'West Computer AS',
#  'Å\xa0tÃ¡tny majetok ZÃ¡vadka Å¡.p.']

# %%
q = select(func.count(Product.manufacturer.distinct()))
session.scalar(q)
# Out:
# 2026-08-28 09:38:53,397 INFO sqlalchemy.engine.Engine SELECT count(DISTINCT products.manufacturer) AS count_1
# FROM products
# 2026-08-28 09:38:53,398 INFO sqlalchemy.engine.Engine [generated in 0.00136s] ()
# 76

# %%
q = (select(Product.manufacturer)
    .group_by(Product.manufacturer)
    .order_by(Product.manufacturer))

session.scalars(q).all()
# Out:
# 2026-08-28 09:48:53,621 INFO sqlalchemy.engine.Engine SELECT products.manufacturer
# FROM products GROUP BY products.manufacturer ORDER BY products.manufacturer
# 2026-08-28 09:48:53,625 INFO sqlalchemy.engine.Engine [generated in 0.00359s] ()
# ['AGAT',
#  'APF Electronics, Inc.',
#  'Acorn Computers Ltd',
#  'Amstrad',
#  'Apple Computer',
#  'Apricot Computers',
#  'Aster Computers',
#  'Atari Corporation',
#  'Atari, Inc.',
#  'Bally Consumer Products',
#  'Brasov Computer',
#  'Camputers',
#  'Coleco',
#  'Commodore',
#  'Comx World Operations',
#  'ComÃ©rcio de Componentes EletrÃ´nicos',
#  'Data Applications International',
#  'Didaktik',
#  'Dragon Data',
#  'Dubna',
#  'EACA',
#  'Elektronika',
#  'Elektronska Industrija NiÅ¡',
#  'Exidy',
#  'Franklin Computer Corporation',
#  'Fujitsu',
#  'GEM',
#  'Gradiente',
#  'Grundy Business Systems',
#  'Honeywell',
#  'IBM',
#  'Intelligent Software',
#  'Intelligent Systems Corporation',
#  'Interact',
#  'Intercompex',
#  'Iskra',
#  'Ivasim',
#  'Jupiter Cantab',
#  'Lambda Electronics',
#  'Luxor',
#  'Matra',
#  'Mattel',
#  'Memotech',
#  'Microbee Systems',
#  'Microdigital Eletronica',
#  'Miles Gordon Technology',
#  'Multitech',
#  'NEC',
#  'NEC Home Electronics',
#  'PEL VaraÅ¾din',
#  'Philips',
#  'Pravetz',
#  'Progeni Systems / Polycorp',
#  'ProlÃ³gica',
#  'Rabbit',
#  'Radio Shack',
#  'Schneider Computer Division',
#  'Sega',
#  'Sharp',
#  'Sinclair Research',
#  'Sord Computer Corporation',
#  'Tangerine Computer Systems',
#  'Technosys',
#  'Tesla',
#  'Texas Instruments',
#  'Thomson',
#  'Timex Sinclair',
#  'Tomy',
#  'Tsinghua University',
#  'VEB Robotron',
#  'Vector',
#  'Videobrain',
#  'Videoton',
#  'Vtech',
#  'West Computer AS',
#  'Å\xa0tÃ¡tny majetok ZÃ¡vadka Å¡.p.']

# %%
q = (select(
    Product.manufacturer,
    func.min(Product.year),
    func.max(Product.year),
    func.count()
    )
    .group_by(Product.manufacturer)
    .order_by(Product.manufacturer))


session.execute(q).all()
# Out:
# 2026-08-28 09:50:12,029 INFO sqlalchemy.engine.Engine SELECT products.manufacturer, min(products.year) AS min_1, max(products.year) AS max_1, count(*) AS count_1
# FROM products GROUP BY products.manufacturer ORDER BY products.manufacturer
# 2026-08-28 09:50:12,030 INFO sqlalchemy.engine.Engine [cached since 24.99s ago] ()
# [('AGAT', 1984, 1984, 1),
#  ('APF Electronics, Inc.', 1979, 1979, 1),
#  ('Acorn Computers Ltd', 1980, 1995, 6),
#  ('Amstrad', 1984, 1990, 7),
#  ('Apple Computer', 1977, 1988, 6),
#  ('Apricot Computers', 1984, 1984, 1),
#  ('Aster Computers', 1982, 1982, 1),
#  ('Atari Corporation', 1985, 1992, 3),
#  ('Atari, Inc.', 1979, 1985, 7),
#  ('Bally Consumer Products', 1977, 1979, 2),
#  ('Brasov Computer', 1986, 1986, 1),
#  ('Camputers', 1983, 1983, 1),
#  ('Coleco', 1983, 1983, 1),
#  ('Commodore', 1977, 1985, 10),
#  ('Comx World Operations', 1983, 1983, 1),
#  ('ComÃ©rcio de Componentes EletrÃ´nicos', 1985, 1985, 1),
#  ('Data Applications International', 1980, 1980, 1),
#  ('Didaktik', 1986, 1987, 3),
#  ('Dragon Data', 1982, 1982, 2),
#  ('Dubna', 1991, 1991, 1),
#  ('EACA', 1980, 1983, 2),
#  ('Elektronika', 1985, 1985, 1),
#  ('Elektronska Industrija NiÅ¡', 1985, 1985, 2),
#  ('Exidy', 1978, 1978, 1),
#  ('Franklin Computer Corporation', 1982, 1982, 1),
#  ('Fujitsu', 1982, 1989, 2),
#  ('GEM', 1985, 1985, 1),
#  ('Gradiente', 1985, 1985, 1),
#  ('Grundy Business Systems', 1982, 1982, 1),
#  ('Honeywell', 1969, 1969, 1),
#  ('IBM', 1984, 1990, 2),
#  ('Intelligent Software', 1985, 1985, 2),
#  ('Intelligent Systems Corporation', 1977, 1977, 1),
#  ('Interact', 1979, 1979, 1),
#  ('Intercompex', 1990, 1990, 1),
#  ('Iskra', 1989, 1989, 1),
#  ('Ivasim', 1983, 1984, 2),
#  ('Jupiter Cantab', 1982, 1982, 1),
#  ('Lambda Electronics', 1985, 1985, 1),
#  ('Luxor', 1978, 1978, 1),
#  ('Matra', 1983, 1983, 1),
#  ('Mattel', 1983, 1983, 1),
#  ('Memotech', 1983, 1983, 3),
#  ('Microbee Systems', 1983, 1983, 1),
#  ('Microdigital Eletronica', 1985, 1985, 1),
#  ('Miles Gordon Technology', 1989, 1989, 1),
#  ('Multitech', 1983, 1983, 1),
#  ('NEC', 1981, 1983, 2),
#  ('NEC Home Electronics', 1981, 1981, 1),
#  ('PEL VaraÅ¾din', 1981, 1984, 2),
#  ('Philips', 1980, 1985, 3),
#  ('Pravetz', 1980, 1985, 3),
#  ('Progeni Systems / Polycorp', 1981, 1981, 1),
#  ('ProlÃ³gica', 1984, 1984, 1),
#  ('Rabbit', 1983, 1983, 1),
#  ('Radio Shack', 1977, 1987, 6),
#  ('Schneider Computer Division', 1988, 1988, 1),
#  ('Sega', 1983, 1983, 1),
#  ('Sharp', 1979, 1987, 3),
#  ('Sinclair Research', 1980, 1984, 4),
#  ('Sord Computer Corporation', 1977, 1982, 2),
#  ('Tangerine Computer Systems', 1983, 1986, 3),
#  ('Technosys', 1984, 1984, 1),
#  ('Tesla', 1985, 1985, 1),
#  ('Texas Instruments', 1979, 1979, 2),
#  ('Thomson', 1982, 1984, 2),
#  ('Timex Sinclair', 1982, 1986, 6),
#  ('Tomy', 1986, 1986, 1),
#  ('Tsinghua University', 1986, 1986, 1),
#  ('VEB Robotron', 1984, 1987, 3),
#  ('Vector', 1987, 1987, 1),
#  ('Videobrain', 1977, 1977, 1),
#  ('Videoton', 1986, 1986, 1),
#  ('Vtech', 1985, 1985, 1),
#  ('West Computer AS', 1984, 1984, 1),
#  ('Å\xa0tÃ¡tny majetok ZÃ¡vadka Å¡.p.', 1989, 1989, 1)]

# %%
q = (
    select(
        Product.manufacturer,
        func.count().label('count'),

    )
    .group_by(Product.manufacturer)
    .having(func.count() >= 5)
    .order_by(Product.manufacturer)
)

session.execute(q).all()
# Out:
# 2026-08-28 10:06:50,315 INFO sqlalchemy.engine.Engine SELECT products.manufacturer, count(*) AS count
# FROM products GROUP BY products.manufacturer
# HAVING count(*) >= ? ORDER BY products.manufacturer
# 2026-08-28 10:06:50,315 INFO sqlalchemy.engine.Engine [generated in 0.00069s] (5,)
# [('Acorn Computers Ltd', 6),
#  ('Amstrad', 7),
#  ('Apple Computer', 6),
#  ('Atari, Inc.', 7),
#  ('Commodore', 10),
#  ('Radio Shack', 6),
#  ('Timex Sinclair', 6)]

# %%
q = select(Product).order_by(Product.name).limit(3)
session.scalars(q).all()
# Out:
# 2026-08-28 10:07:31,466 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products ORDER BY products.name
#  LIMIT ? OFFSET ?
# 2026-08-28 10:07:31,467 INFO sqlalchemy.engine.Engine [generated in 0.00127s] (3, 0)
# [Product(10, "464 Plus"), Product(11, "6128 Plus"), Product(6, "A7000")]
